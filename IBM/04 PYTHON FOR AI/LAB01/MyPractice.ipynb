# %%
# !pip install pandas numpy 
# !pip install lxml
# Out:
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Using cached numpy-2.2.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\my projects\ai\ibm\04 python for ai\lab01\env41\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\my projects\ai\ibm\04 python for ai\lab01\env41\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.2-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.2 pandas-2.2.3 pytz-2024.2 tzdata-2025.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting lxml
#   Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.8 MB 2.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.6/3.8 MB 2.5 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/3.8 MB 2.7 MB/s eta 0:00:01
#    --------------------------- ------------ 2.6/3.8 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 2.7 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-5.3.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %%
URL="https://en.wikipedia.org/wiki/Chiranjeevi_filmography"
tables = pd.read_html(URL)
len(tables)
tables
df1=tables[3]
df2=tables[3]
df3=tables[4]
df1.head()


# Replace the column headers with column numbers
df1.shape[1]
df1.columns = range(df1.shape[1])
df1.head()

# Retain columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
#df1 = df1[[0,2]]
df1.head()

# Retain the Rows with index 1 to 10, indicating the top 10 economies of the world.
#df1 = df1.iloc[1:11,:]


# Assign column names as "Year" and "Movie"
#df1.columns = ['Year','Movie']
df1.head()
# Out:
#    Year                   Title                Position           Notes Ref.
# 0  2005                 Hanuman  Sri Anjaneyulu (voice)  Telugu version  NaN
# 1  2010                  Varudu                Narrator             NaN  NaN
# 2  2013  Jagadguru Adi Shankara                Narrator             NaN  NaN
# 3  2015            Rudhramadevi                Narrator             NaN  NaN
# 4  2017               Gunturodu                Narrator             NaN  NaN
